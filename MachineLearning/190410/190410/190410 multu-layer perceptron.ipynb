# %%
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

# %%
features = 2
iter = 2000
learning_rate = 0.01

# %%
x = np.array([[0,0],[1,0],[0,1],[1,1]],np.float32)

# %%
y = np.array([0,1,1,0],np.float32).reshape(-1,1)

# %%
x1 = tf.placeholder(tf.float32,[None,2])
y1 = tf.placeholder(tf.float32,[None,1])

# %%
# weight1 = tf.Variable(tf.random_normal([2,2]))
# weight2 = tf.Variable(tf.random_normal([2,1]))
weights ={
"w_h1" : tf.Variable(tf.random_normal([2,2])),
"w_out" : tf.Variable(tf.random_normal([2,1]))
}

biases ={
    "b_h1" : tf.Variable(tf.zeros([2])),
    "b_out" : tf.Variable(tf.zeros([1]))
}

# %%
biases
# Out:
# {'b_h1': <tf.Variable 'Variable_18:0' shape=(2,) dtype=float32_ref>,
#  'b_out': <tf.Variable 'Variable_19:0' shape=(1,) dtype=float32_ref>}

# %%
def test_xor(x, weights, biases):
    hiddenLayer1 = tf.add(tf.matmul(x, weights['w_h1']), biases['b_h1'])
    hiddenLayer1 = tf.nn.sigmoid(hiddenLayer1)
    outLayer1 = tf.add(tf.matmul(x, weights['w_out']), biases['b_out'])
    return outLayer1

# %%
x1,y1
# Out:
# (<tf.Tensor 'Placeholder_8:0' shape=(?, 2) dtype=float32>,
#  <tf.Tensor 'Placeholder_9:0' shape=(?, 1) dtype=float32>)

# %%
model = test_xor(x, weights, biases)

# %%
model
# Out:
# <tf.Tensor 'Add_11:0' shape=(4, 1) dtype=float32>

# %%
loss_func = tf.reduce_mean(tf.nn.sigmoid_cross_entropy_with_logits(logits=model,labels=y))

# %%
optimizer = tf.train.GradientDescentOptimizer(learning_rate=0.01).minimize(loss_func)

# %%
sess = tf.Session()
sess.run(tf.global_variables_initializer())

# %%
for k in range(iter):
  tmp_cost, _ =sess.run([loss_func,optimizer],feed_dict={x1:x,y1:y})
  print(tmp_cost)
# Out:
# 0.759361
# 0.7589587
# 0.758559
# 0.7581619
# 0.75776726
# 0.7573753
# 0.75698584
# 0.7565989
# 0.7562144
# 0.75583243
# 0.75545293
# 0.75507593
# 0.7547014
# 0.75432914
# 0.7539595
# 0.75359213
# 0.75322723
# 0.75286466
# 0.7525044
# 0.75214666
# 0.7517912
# 0.751438
# 0.7510871
# 0.7507386
# 0.7503923
# 0.7500484
# 0.7497065
# 0.7493671
# 0.7490299
# 0.74869484
# 0.748362
# 0.7480314
# 0.74770296
# 0.7473766
# 0.7470525
# 0.74673057
# 0.74641067
# 0.746093
# 0.7457773
# 0.7454638
# 0.74515235
# 0.74484295
# 0.7445356
# 0.7442304
# 0.74392706
# 0.7436258
# 0.7433266
# 0.74302936
# 0.7427341
# 0.74244076
# 0.74214953
# 0.7418601
# 0.7415727
# 0.7412871
# 0.7410035
# 0.7407218
# 0.74044204
# 0.74016404
# 0.73988795
# 0.7396138
# 0.7393414
# 0.73907083
# 0.73880213
# 0.7385352
# 0.73827004
# 0.7380067
# 0.7377451
# 0.73748535
# 0.7372272
# 0.73697096
# 0.73671645
# 0.73646355
# 0.7362124
# 0.735963
# 0.7357152
# 0.73546904
# 0.73522466
# 0.7349819
# 0.7347408
# 0.73450136
# 0.7342635
# ...
