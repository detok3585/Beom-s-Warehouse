# %%
#Linear Regression

# %%
#!pip install keras

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense, Activation
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.linspace(1,2,200)
y = x*4 + np.random.randn(*x.shape)*0.3
# plt.scatter(x,y)
# plt.show()

# %%
# create model
model = Sequential()
model.add(Dense(1, input_dim=1,activation='linear'))

# %% [markdown]
# **메트릭은 평가 기준을 말합니다.**
# - compile() 함수의 metrics 인자로 여러 개의 평가 기준을 지정할 수 있습니다.
#  - Mean square error, 평균오차제곱
#
#
#  **Loss function 손실함수**
#  - 내 모델을 통해 생성된 결과 값과 실제로 발생하기를 원했던 값간의 차이를 계산하는 함수.
#  - 목적에 따라 여러 종류의 함수가 존재할 수 있다

# %%
model.compile(optimizer='sgd',loss='mse',metrics=['mse'])

# %%
weights = model.layers[0].get_weights()
w_init = weights[0][0][0]
b_init = weights[1][0]
w_init, b_init
# Out:
# (-1.6402154, 0.0)

# %%
model.fit(x,y, batch_size=1,epochs=30,shuffle=False)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Epoch 1/30
# 200/200 [==============================] - 0s 2ms/step - loss: 2.3769 - mean_squared_error: 2.3769
# Epoch 2/30
# 200/200 [==============================] - 0s 777us/step - loss: 0.2293 - mean_squared_error: 0.2293
# Epoch 3/30
# 200/200 [==============================] - 0s 871us/step - loss: 0.2189 - mean_squared_error: 0.2189
# Epoch 4/30
# 200/200 [==============================] - 0s 937us/step - loss: 0.2093 - mean_squared_error: 0.2093
# Epoch 5/30
# 200/200 [==============================] - 0s 876us/step - loss: 0.2005 - mean_squared_error: 0.2005
# Epoch 6/30
# 200/200 [==============================] - 0s 914us/step - loss: 0.1924 - mean_squared_error: 0.1924
# Epoch 7/30
# 200/200 [==============================] - 0s 917us/step - loss: 0.1850 - mean_squared_error: 0.1850
# Epoch 8/30
# 200/200 [==============================] - 0s 890us/step - loss: 0.1782 - mean_squared_error: 0.1782
# Epoch 9/30
# 200/200 [==============================] - 0s 977us/step - loss: 0.1719 - mean_squared_error: 0.1719
# Epoch 10/30
# 200/200 [==============================] - 0s 918us/step - loss: 0.1661 - mean_squared_error: 0.1661
# Epoch 11/30
# 200/200 [==============================] - 0s 919us/step - loss: 0.1608 - mean_squared_error: 0.1608
# Epoch 12/30
# 200/200 [==============================] - 0s 818us/step - loss: 0.1559 - mean_squared_error: 0.1559
# Epoch 13/30
# 200/200 [==============================] - 0s 805us/step - loss: 0.1514 - mean_squared_error: 0.1514
# Epoch 14/30
# 200/200 [==============================] - 0s 837us/step - loss: 0.1473 - mean_squared_error: 0.1473
# Epoch 15/30
# 200/200 [==============================] - 0s 820us/step - loss: 0.1435 - mean_squared_error: 0.1435
# Epoch 16/30
# 200/200 [==============================] - 0s 803us/step - loss: 0.1400 - mean_squared_error: 0.1400
# Epoch 17/30
# 200/200 [==============================] - 0s 829us/step - loss: 0.1368 - mean_squared_error: 0.1368
# Epoch 18/30
# 200/200 [==============================] - 0s 842us/step - loss: 0.1338 - mean_squared_error: 0.1338
# Epoch 19/30
# 200/200 [==============================] - 0s 892us/step - loss: 0.1311 - mean_squared_error: 0.1311
# Epoch 20/30
# 200/200 [==============================] - 0s 807us/step - loss: 0.1286 - mean_squared_error: 0.1286
# Epoch 21/30
# 200/200 [==============================] - 0s 804us/step - loss: 0.1263 - mean_squared_error: 0.1263
# Epoch 22/30
# 200/200 [==============================] - 0s 836us/step - loss: 0.1242 - mean_squared_error: 0.1242
# Epoch 23/30
# 200/200 [==============================] - 0s 833us/step - loss: 0.1223 - mean_squared_error: 0.1223
# Epoch 24/30
# 200/200 [==============================] - 0s 860us/step - loss: 0.1205 - mean_squared_error: 0.1205
# Epoch 25/30
# 200/200 [==============================] - 0s 848us/step - loss: 0.1189 - mean_squared_error: 0.1189
# Epoch 26/30
# 200/200 [==============================] - 0s 795us/step - loss: 0.1174 - mean_squared_error: 0.1174
# Epoch 27/30
# 200/200 [==============================] - 0s 814us/step - loss: 0.1160 - mean_squared_error: 0.1160
# Epoch 28/30
# 200/200 [==============================] - 0s 822us/step - loss: 0.1147 - mean_squared_error: 0.1147
# Epoch 29/30
# 200/200 [==============================] - 0s 797us/step - loss: 0.1136 - mean_squared_error: 0.1136
# Epoch 30/30
# 200/200 [==============================] - 0s 843us/step - loss: 0.1125 - mean_squared_error: 0.1125

# %%
predict = model.predict(x)
plt.plot(x,predict,'b',x,y,'k.')
plt.show()

# %% [markdown]
# 가<br /><br /><br /><br /><br />나
